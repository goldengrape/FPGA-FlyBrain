# %% [markdown]
# # Lesson 8 Exercise: Write a minimal oracle for a self-checking testbench
#
# This workbook corresponds to **Lesson 8: How do we know the hardware is correct?**
#
# A real testbench samples DUT outputs after clock edges and compares them with expected values. This exercise reduces that idea to one pure Python function: find the first point where a sampled waveform diverges from its oracle.

# %% [markdown]
# ## Before coding
#
# Assume each tuple is a post-edge sample `(membrane_v, spike)`:
#
# - expected = `[(1, False), (2, False), (0, True)]`
# - actual   = `[(1, False), (3, False), (0, True)]`
#
# At what cycle index does the first mismatch occur?
#
# Now suppose actual contains only the first two samples while expected contains three. Even if the common prefix matches, why must the test still fail?

# %% [markdown]
# ## Implement the function
#
# ### What does this function do?
#
# `check_sampled_trace()` models the post-sampling comparison part of a self-checking testbench. It does not generate a clock or execute RTL; it compares already-sampled DUT results with an oracle.
#
# ### Inputs
#
# - `actual`: sampled DUT results, each item `(membrane_v, spike)`;
# - `expected`: oracle samples in the same format.
#
# Do not modify either input list.
#
# ### Output
#
# Return exactly:
#
# `(passed, first_bad_cycle)`
#
# 1. If both lists have equal length and every sample matches, return `(True, None)`.
# 2. If a shared cycle first differs, return `(False, cycle_index)`.
# 3. If the common prefix matches but lengths differ, return `(False, min(len(actual), len(expected)))`, the position of the first missing or extra sample.

# %%
def check_sampled_trace(
    actual: list[tuple[int, bool]],
    expected: list[tuple[int, bool]],
) -> tuple[bool, int | None]:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: find the first sampled-trace mismatch")
    # YOUR CODE ENDS HERE

# %% [markdown]
# ## Check your implementation
#
# The grader checks exact matches, value/Boolean divergence, length mismatch, and input immutability. This Python check does not replace the real Icarus testbench; it practices the core oracle decision inside a self-checking testbench.

# %%
# Course infrastructure: make the repository root importable from a notebook subdirectory.
from pathlib import Path
import sys

_repo_root = next(
    (
        path
        for path in (Path.cwd(), *Path.cwd().parents)
        if (path / "exercises" / "grader").is_dir()
    ),
    None,
)
if _repo_root is None:
    raise FileNotFoundError(
        "Could not find the FPGA-FlyBrain repository root. Open this exercise from inside the repository; preferably create a personal work copy with scripts/start_exercise.py first. / 未找到 FPGA-FlyBrain 仓库根目录。请从仓库内部打开此作业 Notebook；推荐先用 scripts/start_exercise.py 创建个人作业副本。"
    )
if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

from exercises.grader.lesson08 import check

check(
    check_sampled_trace=check_sampled_trace,
    language="en",
)

# %% [markdown]
# ## Human Check
#
# 1. What different jobs are served by a self-checking testbench and a waveform viewer?
# 2. Why is a correct common prefix insufficient when the sampled trace is truncated?
# 3. What can happen when the expected oracle itself is wrong?
# 4. This exercise generates no clock and runs no RTL. Which part of Lesson 8 still requires a real simulator?
