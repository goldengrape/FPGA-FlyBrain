# %% [markdown]
# # Lesson 6 Exercise: Translate one RTL clock edge into Python semantics
#
# This workbook corresponds to **Lesson 6: What is RTL?**
#
# You do not write SystemVerilog here. Treat the lesson's `clocked_accumulator` as an existing RTL module and state exactly what its register should contain after one rising edge.

# %% [markdown]
# ## Before coding
#
# Predict two rising edges by hand:
#
# 1. Before the edge: `state=7`, `input_value=-2`, `rst_n=True`. What is state after the edge?
# 2. Before the edge: `state=99`, `input_value=3`, `rst_n=False`. What is state after the edge?
#
# This exercise uses values that do not overflow 8-bit signed arithmetic. The teaching RTL currently wraps at finite width, but overflow policy is not the formal neuron semantic being frozen here.

# %% [markdown]
# ## Implement the function
#
# ### What does this function do?
#
# `clocked_accumulator_edge()` models the state update caused by **one rising clock edge** of `clocked_accumulator`.
#
# ### Inputs
#
# - `state`: old value stored in the register before the edge;
# - `input_value`: value to accumulate on this edge;
# - `rst_n`: synchronous active-low reset; `False` means reset is taken on this edge.
#
# ### Output
#
# Return **one integer**: the new `state` stored after this rising edge.
#
# - If `rst_n=False`, return `0`; reset takes precedence over accumulation.
# - If `rst_n=True`, return `state + input_value`.
#
# The function models one edge only and does not keep hidden state between calls.

# %%
def clocked_accumulator_edge(
    state: int,
    input_value: int,
    rst_n: bool,
) -> int:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: translate one rising-edge RTL update")
    # YOUR CODE ENDS HERE

# %% [markdown]
# ## Check your implementation
#
# The grader checks normal accumulation, reset precedence, and whether chained edges really use the previously stored state. Concrete hidden vectors are not shown in the workbook.

# %%
# Course infrastructure: make the repository root importable from a notebook subdirectory.
from pathlib import Path
import sys

_repo_root = next(
    (
        path
        for path in (Path.cwd(), *Path.cwd().parents)
        if (path / "exercises" / "grader").is_dir()
    ),
    None,
)
if _repo_root is None:
    raise FileNotFoundError(
        "Could not find the FPGA-FlyBrain repository root. Open this exercise from inside the repository; preferably create a personal work copy with scripts/start_exercise.py first. / 未找到 FPGA-FlyBrain 仓库根目录。请从仓库内部打开此作业 Notebook；推荐先用 scripts/start_exercise.py 创建个人作业副本。"
    )
if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

from exercises.grader.lesson06 import check

check(
    clocked_accumulator_edge=clocked_accumulator_edge,
    language="en",
)

# %% [markdown]
# ## Human Check
#
# 1. Why must reset take precedence instead of accumulating first and then resetting?
# 2. Does this Python function correspond to a combinational relation or a clocked register update?
# 3. Why does a correct Python function still not prove that the real RTL passes simulation?
# 4. If you want to observe real 8-bit overflow, why should you return to the teaching RTL/toolchain instead of silently turning that behavior into this exercise's formal policy?
