# %% [markdown]
# # Lesson 17 Exercise：Estimate burst cost for sequential/random access
#
# Do not simulate a real DDR controller. Convert an address pattern into burst count and a minimal cycle-cost model.

# %% [markdown]
# ## Before coding
#
# Compare:
#
# - `[0,1,2,3,4]`, max burst=4;
# - `[0,10,20,30,40]`, max burst=4.
#
# With setup=5 cycles/burst and 1 cycle/word, find burst count and total cycles.

# %% [markdown]
# ## Implement the function
#
# ### What does this function do?
#
# `estimate_burst_cycles()` scans word addresses in request order and merges consecutive addresses into the same burst, up to `max_burst_words`.
#
# ### Inputs
#
# - `addresses`: requested word indices in order;
# - `max_burst_words`: maximum words per burst;
# - `setup_cycles`: fixed cost per burst;
# - `word_cycles`: cost per transferred word.
#
# **Valid input domain for this exercise:** `max_burst_words >= 1`, `setup_cycles >= 0`, and `word_cycles >= 0`; entries in `addresses` are integer word indices. You do not need to handle invalid parameters.
#
# ### Output
#
# Return `(burst_count, total_cycles)`:
#
# - empty input returns `(0, 0)`;
# - continue a burst only when `current == previous + 1` and it is not full;
# - `total_cycles = burst_count * setup_cycles + len(addresses) * word_cycles`.

# %%
def estimate_burst_cycles(
    addresses: list[int],
    max_burst_words: int,
    setup_cycles: int,
    word_cycles: int = 1,
) -> tuple[int, int]:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: group consecutive addresses into bursts and compute cycles")
    # YOUR CODE ENDS HERE

# %% [markdown]
# ## Check your implementation
#
# The grader checks the core semantics without displaying concrete test vectors in the workbook.

# %%
# Course infrastructure: make the repository root importable from a notebook subdirectory.
from pathlib import Path
import sys

_repo_root = next(
    path for path in (Path.cwd(), *Path.cwd().parents)
    if (path / "exercises" / "grader").is_dir()
)
if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

from exercises.grader.lesson17 import check

check(estimate_burst_cycles=estimate_burst_cycles, language="en")

# %% [markdown]
# ## Human Check
#
# Explain why equal word counts can produce different burst counts, why this is only an access-pattern model, and why integrity testing comes before bandwidth benchmarking.
