# %% [markdown]
# # Lesson 21 Exercise: Identify the highest-utilization stage
#
# Practice diagnosing a bottleneck from demand relative to capacity, not from raw workload alone.

# %% [markdown]
# ## Before coding
#
# Stage A has demand 9 and capacity 12. Stage B has demand 5 and capacity 5.
#
# Which stage has the larger raw demand? Which stage has the higher utilization?

# %% [markdown]
# ## Implement the function
#
# ### What does this function do?
#
# `bottleneck()` converts per-stage demand/capacity into utilization and identifies the current highest-utilization stage.
#
# ### Inputs
#
# - `stage_demand`: mapping from stage name to required work rate;
# - `stage_capacity`: mapping from the same stage names to available work rate;
# - assume both dictionaries contain the same keys;
# - assume all capacities are positive;
# - grader cases have a unique highest utilization.
#
# ### Output
#
# Return `(utilization, bottleneck_stage)`:
#
# 1. `utilization[stage] = stage_demand[stage] / stage_capacity[stage]`;
# 2. `bottleneck_stage` is the stage name with the highest utilization.
#
# Do not modify either input dictionary.

# %%
def bottleneck(
    stage_demand: dict[str, float],
    stage_capacity: dict[str, float],
) -> tuple[dict[str, float], str]:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: compute utilization and return the highest-utilization stage")
    # YOUR CODE ENDS HERE

# %% [markdown]
# ## Check your implementation
#
# The grader checks the core semantics without displaying concrete hidden test vectors in the workbook.

# %%
# Course infrastructure: make the repository root importable from a notebook subdirectory.
from pathlib import Path
import sys

_repo_root = next(
    path for path in (Path.cwd(), *Path.cwd().parents)
    if (path / "exercises" / "grader").is_dir()
)
if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

from exercises.grader.lesson21 import check

check(bottleneck=bottleneck, language="en")

# %% [markdown]
# ## Human Check
#
# Why can a stage with less raw demand still be the bottleneck? What measurement would you want before proposing a hardware optimization?
