# %% [markdown]
# # Lesson 5 Exercise: From truth tables to a spike condition
#
# This workbook corresponds to **Lesson 5: What are the basic logical building blocks of a digital circuit?**
#
# The goal is not memorizing Python and/or/not syntax. It is to connect **truth table → Boolean relation → combinational logic**.

# %% [markdown]
# ## Objective
#
# Implement NOT, AND, and OR, then combine a threshold comparator result with enable to form a spike condition.
#
# The threshold_reached specification is fixed: return True when value reaches or exceeds threshold. spike_enabled is already provided and should not be modified.

# %% [markdown]
# ## Before coding: make the logic explicit
#
# Fill these first.
#
# ### A. Two-input logic
#
# | a | b | a AND b | a OR b |
# |---|---|---|---|
# | False | False | ? | ? |
# | False | True  | ? | ? |
# | True  | False | ? | ? |
# | True  | True  | ? | ? |
#
# Also write NOT False and NOT True.
#
# ### B. Comparator + enable
#
# Consider value below threshold, exactly at threshold, and above threshold.
#
# First decide threshold_reached for each position, then explain why enable=False must block the final spike in every case.

# %% [markdown]
# ## Part A: implement the basic gates

# %%
def gate_not(a: bool) -> bool:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: NOT")
    # YOUR CODE ENDS HERE


def gate_and(a: bool, b: bool) -> bool:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: AND")
    # YOUR CODE ENDS HERE


def gate_or(a: bool, b: bool) -> bool:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: OR")
    # YOUR CODE ENDS HERE

# %% [markdown]
# ## Part B: implement the threshold comparator
#
# Its output is another Boolean condition, so it can feed directly into AND.

# %%
def threshold_reached(value: int, threshold: int) -> bool:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: threshold comparison")
    # YOUR CODE ENDS HERE


def spike_enabled(enable: bool, value: int, threshold: int) -> bool:
    return gate_and(enable, threshold_reached(value, threshold))

# %% [markdown]
# ## Check your implementation
#
# The grader checks complete Boolean behavior, the threshold boundary, and enable composition without displaying concrete vectors in the workbook.

# %%
from exercises.grader.lesson05 import check

check(
    gate_not=gate_not,
    gate_and=gate_and,
    gate_or=gate_or,
    threshold_reached=threshold_reached,
    spike_enabled=spike_enabled,
    language="en",
)

# %% [markdown]
# ## Human Check
#
# Check your implementation by asking what would happen if it were wrong:
#
# 1. If gate_and() were accidentally implemented as OR, what kind of input combination would expose the mistake most directly, and why?
# 2. If threshold_reached() used a strict greater-than comparison, what class of boundary input would diverge from the specification?
# 3. If spike_enabled() used OR instead of AND, what incorrect path could allow a spike even while enable is off?
# 4. Map your code back to hardware: what does the comparator output, where do the two AND inputs come from, and what is the final output?
