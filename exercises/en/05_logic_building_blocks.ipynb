# %% [markdown]
# # Lesson 5 Exercise: Logic gates, comparison, and enable
#
# This workbook corresponds to **Lesson 5: What are the basic logical building blocks of a digital circuit?**
#
# This lesson uses Python Boolean expressions as a minimal model of digital logic. You will implement NOT, AND, OR, and a threshold comparator, then see how enable combines with the spike decision.

# %% [markdown]
# ## Task and constraints
#
# Complete gate_not, gate_and, gate_or, and threshold_reached.
#
# The course semantics for threshold_reached are fixed: return True when value reaches or exceeds threshold.
#
# spike_enabled is already provided. Do not modify it; it demonstrates how simple logic composes into a larger condition.

# %% [markdown]
# ## Write your implementation
#
# Edit only the TODO regions below. Function signatures are part of the lesson interface.

# %%
def gate_not(a: bool) -> bool:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: NOT")
    # YOUR CODE ENDS HERE


def gate_and(a: bool, b: bool) -> bool:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: AND")
    # YOUR CODE ENDS HERE


def gate_or(a: bool, b: bool) -> bool:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: OR")
    # YOUR CODE ENDS HERE


def threshold_reached(value: int, threshold: int) -> bool:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: threshold comparison")
    # YOUR CODE ENDS HERE


def spike_enabled(enable: bool, value: int, threshold: int) -> bool:
    return gate_and(enable, threshold_reached(value, threshold))

# %% [markdown]
# ## Check your implementation
#
# This cell only calls the external grader. Concrete grader inputs are not displayed in the Exercise Notebook. Run your implementation cell first, then run this check.

# %%
from exercises.grader.lesson05 import check

check(
    gate_not=gate_not,
    gate_and=gate_and,
    gate_or=gate_or,
    threshold_reached=threshold_reached,
    spike_enabled=spike_enabled,
    language="en",
)

# %% [markdown]
# ## Human Check
#
# 1. Why is the equality case at threshold worth considering separately?
# 2. Which basic logic blocks could represent spike_enabled?
# 3. When enable=False, why should the final output remain False even if the comparator is already True?
