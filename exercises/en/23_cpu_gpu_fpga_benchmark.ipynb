# %% [markdown]
# # Lesson 23 Exercise: Calculate throughput and energy per event
#
# Practice two benchmark metrics without turning synthetic numbers into claims about real CPU/GPU/FPGA hardware.

# %% [markdown]
# ## Before coding
#
# A run processes 1,000 events in 0.5 s while drawing 20 W.
#
# Hand-calculate:
# - events per second;
# - total energy in joules;
# - joules per event.

# %% [markdown]
# ## Implement the function
#
# ### What does this function do?
#
# `benchmark_metrics()` converts one documented benchmark run into throughput and energy per event.
#
# ### Inputs
#
# - `events`: number of completed work units; assume `events > 0`;
# - `seconds`: measured run duration in seconds; assume `seconds > 0`;
# - `watts`: average measured power in watts over the same interval; assume `watts >= 0`.
#
# ### Output
#
# Return `(throughput, energy_per_event)`:
#
# 1. `throughput = events / seconds` in events/s;
# 2. total energy is `watts * seconds` joules;
# 3. `energy_per_event = total_energy / events` in J/event.
#
# The function only computes metrics; it does not decide whether two runs are comparable.

# %%
def benchmark_metrics(
    events: int,
    seconds: float,
    watts: float,
) -> tuple[float, float]:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: return throughput and energy per event")
    # YOUR CODE ENDS HERE

# %% [markdown]
# ## Check your implementation
#
# The grader checks the core semantics without displaying concrete hidden test vectors in the workbook.

# %%
# Course infrastructure: make the repository root importable from a notebook subdirectory.
from pathlib import Path
import sys

_repo_root = next(
    path for path in (Path.cwd(), *Path.cwd().parents)
    if (path / "exercises" / "grader").is_dir()
)
if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

from exercises.grader.lesson23 import check

check(benchmark_metrics=benchmark_metrics, language="en")

# %% [markdown]
# ## Human Check
#
# Two runs produce the same throughput. What additional information is still needed before claiming one CPU/GPU/FPGA implementation is better?
