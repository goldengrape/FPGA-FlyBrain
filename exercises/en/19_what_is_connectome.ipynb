# %% [markdown]
# # Lesson 19 Exercise: Compute connectome in-degree and out-degree
#
# Practice treating a connectome as a directed graph without mixing graph structure with dynamic neuron state.

# %% [markdown]
# ## Before coding
#
# For neuron IDs `[11, 22, 44]` and edges `[(11, 22), (22, 44), (11, 44)]`, predict the in-degree and out-degree of every neuron.
#
# Remember: the direction is source → target.

# %% [markdown]
# ## Implement the function
#
# ### What does this function do?
#
# `degree_summary()` counts directed incoming and outgoing edges for every neuron ID in the supplied graph.
#
# ### Inputs
#
# - `neuron_ids`: all neuron IDs that belong to this graph;
# - `edges`: directed `(source, target)` pairs;
# - assume every source and target in `edges` is present in `neuron_ids`.
#
# ### Output
#
# Return `(in_degree, out_degree)`:
#
# 1. `in_degree[id]` is the number of edges whose target is that neuron;
# 2. `out_degree[id]` is the number of edges whose source is that neuron.
#
# Every neuron in `neuron_ids` must appear in both dictionaries, including neurons with degree zero.
#
# Do not modify the input lists.

# %%
def degree_summary(
    neuron_ids: list[int],
    edges: list[tuple[int, int]],
) -> tuple[dict[int, int], dict[int, int]]:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: count incoming and outgoing directed edges for every neuron")
    # YOUR CODE ENDS HERE

# %% [markdown]
# ## Check your implementation
#
# The grader checks the core semantics without displaying concrete hidden test vectors in the workbook.

# %%
# Course infrastructure: make the repository root importable from a notebook subdirectory.
from pathlib import Path
import sys

_repo_root = next(
    path for path in (Path.cwd(), *Path.cwd().parents)
    if (path / "exercises" / "grader").is_dir()
)
if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

from exercises.grader.lesson19 import check

check(degree_summary=degree_summary, language="en")

# %% [markdown]
# ## Human Check
#
# Why does reversing every edge preserve the total number of edges but change the biological/graph interpretation? Which quantities swap?
