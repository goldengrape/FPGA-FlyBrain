# %% [markdown]
# # Lesson 12 Exercise: Process the complete journey of one source spike
#
# This workbook corresponds to **Lesson 12: The complete journey of one spike**.
#
# You have already met the queue, source index, synapse record, and target accumulator separately. Now connect them: when one source spike arrives, read only that source's synapse range, emit weighted events, and update target accumulators.

# %% [markdown]
# ## What you will complete
#
# process_one_spike() receives source_id, source_index, records, and target_accum.
#
# It must:
#
# 1. find the (start, count) for source_id;
# 2. traverse only that range of records;
# 3. emit the corresponding (target, weight) weighted events;
# 4. add each weight to the target accumulator;
# 5. return a new accumulator and weighted_events.
#
# Do not mutate the input target_accum in place.

# %% [markdown]
# ## Write your implementation
#
# Edit only the TODO regions below. Function signatures are part of the lesson interface.

# %%
def process_one_spike(
    source_id: int,
    source_index: list[tuple[int, int]],
    records: list[tuple[int, int]],
    target_accum: list[int],
) -> tuple[list[int], list[tuple[int, int]]]:
    updated = list(target_accum)

    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: lookup range and apply weighted events")
    # YOUR CODE ENDS HERE

    return updated, weighted_events

# %% [markdown]
# ## Check your implementation
#
# This cell only calls the external grader. Concrete grader inputs are not displayed in the Exercise Notebook. Run your implementation cell first, then run this check.

# %%
from exercises.grader.lesson12 import check

check(process_one_spike=process_one_spike, language="en")

# %% [markdown]
# ## Human Check
#
# Without looking at code, explain separately:
#
# 1. What does the spike queue store?
# 2. What does the source index store?
# 3. What does a synapse record store?
# 4. What does a target accumulator store?
# 5. If a source has count=0, what should happen when its spike is processed?
