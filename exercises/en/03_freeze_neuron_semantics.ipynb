# %% [markdown]
# # Lesson 3 Exercise: Turn “LIF” into an explicit specification
#
# This workbook corresponds to **Lesson 3: Why is “we both use LIF” not enough?**
#
# The same model name can hide different update orders, boundary comparisons, and reset rules. You will implement the frozen v0 semantics and construct examples that distinguish competing rules.

# %% [markdown]
# ## Frozen v0 rules
#
# This lesson fixes:
#
# - candidate = alpha * v + current
# - spike when candidate reaches or exceeds threshold
# - reset immediately after a spike
# - lif_step_v0 returns (next_v, spike, candidate_v)
#
# Also construct two distinguishing examples:
#
# - threshold_boundary_case(): make the candidate land exactly on threshold;
# - update_order_counterexample(): make alpha*v + current differ from alpha*(v+current).

# %% [markdown]
# ## Write your implementation
#
# Edit only the TODO regions below. Function signatures are part of the lesson interface.

# %%
def lif_step_v0(
    v: float,
    current: float,
    alpha: float = 0.9,
    threshold: float = 1.0,
    reset: float = 0.0,
) -> tuple[float, bool, float]:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: implement the frozen v0 semantics")
    # YOUR CODE ENDS HERE

    return next_v, spike, candidate_v


def threshold_boundary_case() -> tuple[float, float, float, float]:
    # Return (v, current, alpha, threshold)
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: construct a threshold boundary case")
    # YOUR CODE ENDS HERE


def update_order_counterexample() -> tuple[float, float, float]:
    # Return (v, current, alpha)
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: construct an update-order counterexample")
    # YOUR CODE ENDS HERE

# %% [markdown]
# ## Check your implementation
#
# This cell only calls the external grader. Concrete grader inputs are not displayed in the Exercise Notebook. Run your implementation cell first, then run this check.

# %%
from exercises.grader.lesson03 import check

check(
    lif_step_v0=lif_step_v0,
    threshold_boundary_case=threshold_boundary_case,
    update_order_counterexample=update_order_counterexample,
    language="en",
)

# %% [markdown]
# ## Human Check
#
# 1. Why can one carefully designed boundary case be more informative than many ordinary random inputs?
# 2. Why is update order part of the specification rather than an implementation detail?
# 3. If RTL later disagrees with Python, which intermediate values would you compare first?
