# %% [markdown]
# # Lesson 13 Exercise：Read a timing budget
#
# No FPGA board or vendor tool is required. The goal is to compute the three most basic timing quantities.

# %% [markdown]
# ## Before coding
#
# Given path delays `[2.0, 4.5, 3.2]` ns and a 5.0 ns clock period, calculate:
#
# 1. the critical path;
# 2. slack;
# 3. whether exactly zero slack passes under this lesson's rule;
# 4. whether changing only the clock target changes RTL logic.

# %% [markdown]
# ## Implement the function
#
# ### What does this function do?
#
# `timing_summary()` reduces a non-empty set of combinational path delays to a minimal timing summary.
#
# ### Inputs
#
# - `path_delays_ns`: candidate path delays in ns;
# - `clock_period_ns`: target clock period in ns.
#
# ### Output
#
# Return exactly `(critical_path_ns, slack_ns, meets_timing)`:
#
# 1. `critical_path_ns`: maximum path delay;
# 2. `slack_ns = clock_period_ns - critical_path_ns`;
# 3. `meets_timing`: Boolean, `True` when slack ≥ 0.

# %%
def timing_summary(
    path_delays_ns: list[float],
    clock_period_ns: float,
) -> tuple[float, float, bool]:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: compute critical path, slack, and timing result")
    # YOUR CODE ENDS HERE

# %% [markdown]
# ## Check your implementation
#
# The grader checks the core semantics without displaying concrete test vectors in the workbook.

# %%
# Course infrastructure: make the repository root importable from a notebook subdirectory.
from pathlib import Path
import sys

_repo_root = next(
    path for path in (Path.cwd(), *Path.cwd().parents)
    if (path / "exercises" / "grader").is_dir()
)
if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

from exercises.grader.lesson13 import check

check(timing_summary=timing_summary, language="en")

# %% [markdown]
# ## Human Check
#
# Explain why the maximum delay defines the critical path, what negative slack means, and why timing does not replace functional simulation.
