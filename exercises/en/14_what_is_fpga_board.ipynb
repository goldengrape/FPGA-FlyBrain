# %% [markdown]
# # Lesson 14 Exercise：Turn a board clock into an observable tick
#
# Translate a fast board clock into a much slower observable tick. Assume exact divisibility.

# %% [markdown]
# ## Before coding
#
# Work out:
#
# - 12 Hz input and 3 Hz target tick: cycles per tick?
# - bits required for `0..cycles_per_tick-1`?
# - when every cycle produces a tick, this exercise still returns at least one bit.

# %% [markdown]
# ## Implement the function
#
# ### What does this function do?
#
# `clock_divider_plan()` computes minimal parameters for a first board-counter experiment.
#
# ### Inputs
#
# - `input_clock_hz`: input clock cycles per second;
# - `target_tick_hz`: desired slow ticks per second.
#
# Both are positive integers and divide evenly here. You do not need to handle zero, negative, or non-divisible inputs.
#
# ### Output
#
# Return `(cycles_per_tick, counter_bits)`:
#
# 1. `cycles_per_tick = input_clock_hz // target_tick_hz`;
# 2. `counter_bits` is the minimum width for `0..cycles_per_tick-1`, with a minimum of one bit.

# %%
def clock_divider_plan(
    input_clock_hz: int,
    target_tick_hz: int,
) -> tuple[int, int]:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: compute cycles per tick and counter width")
    # YOUR CODE ENDS HERE

# %% [markdown]
# ## Check your implementation
#
# The grader checks the core semantics without displaying concrete test vectors in the workbook.

# %%
# Course infrastructure: make the repository root importable from a notebook subdirectory.
from pathlib import Path
import sys

_repo_root = next(
    path for path in (Path.cwd(), *Path.cwd().parents)
    if (path / "exercises" / "grader").is_dir()
)
if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

from exercises.grader.lesson14 import check

check(clock_divider_plan=clock_divider_plan, language="en")

# %% [markdown]
# ## Human Check
#
# Explain the roles of the clock source, counter state, and observable I/O, and why 100 MHz can drive a visible change at only a few hertz.
