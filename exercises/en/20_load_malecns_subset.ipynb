# %% [markdown]
# # Lesson 20 Exercise: Build a minimal image manifest
#
# Practice the integrity contract used before software-vs-FPGA differential testing. The payload here is generic bytes; this exercise does not claim to contain real MaleCNS data.

# %% [markdown]
# ## Before coding
#
# Suppose two files have the same name but different bytes. Can a file name prove they are the same image?
#
# What information would you record so another machine can verify the exact payload?

# %% [markdown]
# ## Implement the function
#
# ### What does this function do?
#
# `image_manifest()` creates a minimal integrity description for one exact binary payload.
#
# ### Inputs
#
# - `payload`: the exact image bytes;
# - `schema_version`: the version string describing how those bytes should be interpreted.
#
# ### Output
#
# Return a dictionary with exactly these keys:
#
# - `"schema_version"`: copy the input version string;
# - `"byte_count"`: `len(payload)`;
# - `"sha256"`: the lowercase hexadecimal SHA-256 digest of the exact payload bytes.
#
# The function must be deterministic and must not modify `payload`.

# %%
import hashlib

def image_manifest(
    payload: bytes,
    schema_version: str,
) -> dict[str, object]:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: return schema version, byte count, and SHA-256 digest")
    # YOUR CODE ENDS HERE

# %% [markdown]
# ## Check your implementation
#
# The grader checks the core semantics without displaying concrete hidden test vectors in the workbook.

# %%
# Course infrastructure: make the repository root importable from a notebook subdirectory.
from pathlib import Path
import sys

_repo_root = next(
    path for path in (Path.cwd(), *Path.cwd().parents)
    if (path / "exercises" / "grader").is_dir()
)
if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

from exercises.grader.lesson20 import check

check(image_manifest=image_manifest, language="en")

# %% [markdown]
# ## Human Check
#
# If two consumers report the same SHA-256 digest, what has been established? What has **not** yet been established about neural correctness?
