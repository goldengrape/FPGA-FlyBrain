# %% [markdown]
# # Lesson 20 Exercise: Build an image manifest with provenance
#
# Practice the image-integrity contract used before a real MaleCNS subset is loaded. The payload here is generic bytes; this exercise does not claim to contain real MaleCNS data.

# %% [markdown]
# ## Before coding
#
# Suppose two files have the same name and the same bytes, but one came from source release A and the other from source release B. Can the checksum tell you that the provenance differs?
#
# What must the manifest record so another machine can verify both the **exact payload** and its **source/conversion rule**?

# %% [markdown]
# ## Implement the function
#
# ### What does this function do?
#
# `image_manifest()` creates a minimal teaching manifest that records both integrity and provenance for one exact binary payload.
#
# ### Inputs
#
# - `payload`: the exact image bytes;
# - `schema_version`: schema version used to interpret the bytes;
# - `source_release`: source-data release / fixture identifier;
# - `converter_version`: converter version that produced the image.
#
# ### Output
#
# Return a dictionary with **exactly** these keys:
#
# - `"schema_version"`: copy the input schema version;
# - `"source_release"`: copy the input source release;
# - `"converter_version"`: copy the input converter version;
# - `"byte_count"`: `len(payload)`;
# - `"sha256"`: the lowercase hexadecimal SHA-256 digest of the exact payload bytes.
#
# The function must be deterministic and must not modify `payload`.

# %%
import hashlib

def image_manifest(
    payload: bytes,
    schema_version: str,
    source_release: str,
    converter_version: str,
) -> dict[str, object]:
    # YOUR CODE STARTS HERE
    raise NotImplementedError(
        "TODO: return schema/provenance fields, byte count, and SHA-256 digest"
    )
    # YOUR CODE ENDS HERE

# %% [markdown]
# ## Check your implementation
#
# The grader checks the core semantics without displaying concrete hidden test vectors in the workbook.

# %%
# Course infrastructure: make the repository root importable from a notebook subdirectory.
from pathlib import Path
import sys

_repo_root = next(
    (
        path
        for path in (Path.cwd(), *Path.cwd().parents)
        if (path / "exercises" / "grader").is_dir()
    ),
    None,
)
if _repo_root is None:
    raise FileNotFoundError(
        "Could not find the FPGA-FlyBrain repository root. Open this exercise from inside the repository; preferably create a personal work copy with scripts/start_exercise.py first."
    )
if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

from exercises.grader.lesson20 import check

check(image_manifest=image_manifest, language="en")

# %% [markdown]
# ## Human Check
#
# If two consumers have the same SHA-256 but different `source_release` or `converter_version`, what does that mean? In your implementation, which lines establish integrity and which establish provenance?
