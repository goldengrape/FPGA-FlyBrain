# %% [markdown]
# # Lesson 16 Exercise：Identify the compute or data-movement bottleneck
#
# Use Lesson 16's deliberately non-overlapped model. The goal is correct units and relative cost, not a final performance model.

# %% [markdown]
# ## Before coding
#
# Calculate: 100 items, 8 bytes/item, 2 ns compute/item, 2 bytes/ns bandwidth, and 20 ns startup latency.
#
# Find compute time, transfer time, and which is larger.

# %% [markdown]
# ## Implement the function
#
# ### What does this function do?
#
# `transfer_profile()` compares arithmetic time with data-movement time for a batch.
#
# ### Inputs
#
# - `num_items`: number of items;
# - `bytes_per_item`: bytes moved per item;
# - `compute_ns_per_item`: arithmetic time per item;
# - `bandwidth_bytes_per_ns`: effective bandwidth;
# - `startup_latency_ns`: fixed transfer startup latency.
#
# ### Output
#
# Return `(compute_ns, transfer_ns, bottleneck)`:
#
# - `compute_ns = num_items * compute_ns_per_item`;
# - `transfer_ns = startup_latency_ns + num_items * bytes_per_item / bandwidth_bytes_per_ns`;
# - bottleneck is `"compute"`, `"memory"`, or `"balanced"` when equal.

# %%
def transfer_profile(
    num_items: int,
    bytes_per_item: int,
    compute_ns_per_item: float,
    bandwidth_bytes_per_ns: float,
    startup_latency_ns: float = 0.0,
) -> tuple[float, float, str]:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: compute compute time, transfer time, and bottleneck")
    # YOUR CODE ENDS HERE

# %% [markdown]
# ## Check your implementation
#
# The grader checks the core semantics without displaying concrete test vectors in the workbook.

# %%
# Course infrastructure: make the repository root importable from a notebook subdirectory.
from pathlib import Path
import sys

_repo_root = next(
    path for path in (Path.cwd(), *Path.cwd().parents)
    if (path / "exercises" / "grader").is_dir()
)
if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

from exercises.grader.lesson16 import check

check(transfer_profile=transfer_profile, language="en")

# %% [markdown]
# ## Human Check
#
# Explain why the model assumes no compute/transfer overlap, why bandwidth units must match, and why a bottleneck change does not change neuron semantics.
