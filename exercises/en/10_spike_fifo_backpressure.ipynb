# %% [markdown]
# # Lesson 10 Exercise: Bounded FIFO and backpressure
#
# This workbook corresponds to **Lesson 10: Why do spikes need a queue?**
#
# Events may be produced faster than they are consumed, so the system needs a First-In, First-Out (FIFO) queue. A real hardware queue has finite capacity; when it fills, backpressure behavior must be explicit.

# %% [markdown]
# ## What you will complete
#
# - fifo_push() returns (new_queue, accepted);
# - append the event when space is available;
# - when full, return accepted=False and leave all old events untouched;
# - fifo_pop() removes the oldest event from the front;
# - popping an empty queue returns None.
#
# A blocked event is not lost; the caller may retry the same event after space becomes available.

# %% [markdown]
# ## Write your implementation
#
# Edit only the TODO regions below. Function signatures are part of the lesson interface.

# %%
def fifo_push(
    queue: list[int],
    event: int,
    capacity: int,
) -> tuple[list[int], bool]:
    result = list(queue)
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: bounded push")
    # YOUR CODE ENDS HERE
    return result, accepted


def fifo_pop(queue: list[int]) -> tuple[list[int], int | None]:
    result = list(queue)
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: FIFO pop")
    # YOUR CODE ENDS HERE
    return result, popped

# %% [markdown]
# ## Check your implementation
#
# This cell only calls the external grader. Concrete grader inputs are not displayed in the Exercise Notebook. Run your implementation cell first, then run this check.

# %%
from exercises.grader.lesson10 import check

check(fifo_push=fifo_push, fifo_pop=fifo_pop, language="en")

# %% [markdown]
# ## Human Check
#
# 1. Why must a full queue not overwrite the oldest spike?
# 2. Does accepted=False mean the event was processed, or that the caller must still retain it?
# 3. What information is backpressure protecting from loss?
