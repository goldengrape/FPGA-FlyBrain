# %% [markdown]
# # Lesson 9 Exercise: One engine serving many states
#
# This workbook corresponds to **Lesson 9: How can one compute unit serve many neurons?**
#
# The key idea is to split a “neuron” into many states stored in memory and one compute engine reused over time. An address selects which state the engine serves now.

# %% [markdown]
# ## What you will complete
#
# - update_addressed_state(): copy the input list and update only the addressed element;
# - round_robin_pass(): serve addresses 0, 1, 2, ... once each and record (address, before, after).
#
# Do not confuse address with state; it is only an index into state memory. Reject a pass when the number of inputs does not match the number of states.

# %% [markdown]
# ## Write your implementation
#
# Edit only the TODO regions below. Function signatures are part of the lesson interface.

# %%
def update_addressed_state(
    states: list[int],
    address: int,
    input_value: int,
) -> list[int]:
    result = list(states)
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: update only the selected address")
    # YOUR CODE ENDS HERE
    return result


def round_robin_pass(
    states: list[int],
    inputs: list[int],
) -> tuple[list[int], list[tuple[int, int, int]]]:
    if len(states) != len(inputs):
        raise ValueError("states and inputs must have the same length")

    current = list(states)
    trace: list[tuple[int, int, int]] = []

    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: serve every address in order")
    # YOUR CODE ENDS HERE

    return current, trace

# %% [markdown]
# ## Check your implementation
#
# This cell only calls the external grader. Concrete grader inputs are not displayed in the Exercise Notebook. Run your implementation cell first, then run this check.

# %%
from exercises.grader.lesson09 import check

check(
    update_addressed_state=update_addressed_state,
    round_robin_pass=round_robin_pass,
    language="en",
)

# %% [markdown]
# ## Human Check
#
# 1. What does an address store, and what does a neuron state store?
# 2. Why can time multiplexing reduce the number of physical compute units without eliminating state storage?
# 3. If the engine serves one address per cycle, how many service operations are needed for N states?
