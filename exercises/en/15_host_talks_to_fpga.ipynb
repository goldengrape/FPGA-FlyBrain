# %% [markdown]
# # Lesson 15 Exercise：Model a host ↔ programmable-logic roundtrip
#
# Use a tiny command sequence to model host/PL control semantics. It is not a real bus implementation; focus on persistent state and ordering.

# %% [markdown]
# ## Before coding
#
# Starting from `initial_register=3`, trace:
#
# `[("read", None), ("add", 4), ("read", None), ("write", 1), ("read", None)]`
#
# Write the readbacks and final register.

# %% [markdown]
# ## Implement the function
#
# ### What does this function do?
#
# `run_host_pl_commands()` executes host commands in order and treats `register` as persistent PL state.
#
# ### Inputs
#
# - `commands`: each item is `(op, value)`;
# - `"write"`: `register = value`;
# - `"add"`: `register += value`;
# - `"read"`: append the current register to readbacks and ignore value;
# - `initial_register`: PL register value before the first command.
#
# ### Output
#
# Return `(readbacks, final_register)`. Readbacks must preserve the time order of read commands.

# %%
def run_host_pl_commands(
    commands: list[tuple[str, int | None]],
    initial_register: int = 0,
) -> tuple[list[int], int]:
    register = initial_register
    readbacks: list[int] = []

    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: execute write/add/read commands in order")
    # YOUR CODE ENDS HERE

    return readbacks, register

# %% [markdown]
# ## Check your implementation
#
# The grader checks the core semantics without displaying concrete test vectors in the workbook.

# %%
# Course infrastructure: make the repository root importable from a notebook subdirectory.
from pathlib import Path
import sys

_repo_root = next(
    path for path in (Path.cwd(), *Path.cwd().parents)
    if (path / "exercises" / "grader").is_dir()
)
if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

from exercises.grader.lesson15 import check

check(run_host_pl_commands=run_host_pl_commands, language="en")

# %% [markdown]
# ## Human Check
#
# Explain why the register persists across commands, why read observes without modifying state, and where this Python model stops short of a real host↔FPGA read/write roundtrip.
