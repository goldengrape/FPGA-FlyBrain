# %% [markdown]
# # Lesson 18 Exercise：Identify VALID/READY accepted data beats
#
# Train only the minimal AXI-style handshake rule; do not implement a complete AXI channel.

# %% [markdown]
# ## Before coding
#
# Trace:
#
# - VALID = `[1,1,1,0]`
# - READY = `[1,0,1,1]`
# - DATA = `[5,6,6,9]`
#
# Which cycles transfer? Why is DATA=6 on cycle 1 not yet accepted?

# %% [markdown]
# ## Implement the function
#
# ### What does this function do?
#
# `accepted_beats()` extracts completed beats from per-cycle VALID/READY/data traces. Assume all three lists have equal length.
#
# ### Inputs
#
# - `valid[cycle]`: sender says the payload is valid;
# - `ready[cycle]`: receiver can accept;
# - `data[cycle]`: current payload.
#
# ### Output
#
# Return `(accepted_data, accepted_cycles)`:
#
# - accept only where `valid[cycle] and ready[cycle]` are both true;
# - `accepted_data` preserves time order;
# - `accepted_cycles` stores the transfer cycle indices.

# %%
def accepted_beats(
    valid: list[bool],
    ready: list[bool],
    data: list[int],
) -> tuple[list[int], list[int]]:
    accepted_data: list[int] = []
    accepted_cycles: list[int] = []

    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: accept beats only where VALID and READY are both true")
    # YOUR CODE ENDS HERE

    return accepted_data, accepted_cycles

# %% [markdown]
# ## Check your implementation
#
# The grader checks the core semantics without displaying concrete test vectors in the workbook.

# %%
# Course infrastructure: make the repository root importable from a notebook subdirectory.
from pathlib import Path
import sys

_repo_root = next(
    path for path in (Path.cwd(), *Path.cwd().parents)
    if (path / "exercises" / "grader").is_dir()
)
if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

from exercises.grader.lesson18 import check

check(accepted_beats=accepted_beats, language="en")

# %% [markdown]
# ## Human Check
#
# Explain why VALID=1/READY=0 is a stall, why READY=1/VALID=0 still has no payload, and how this relates to Lesson 10 backpressure.
