# %% [markdown]
# # Lesson 22 Exercise: Generate a deterministic closed-loop position trace
#
# Practice the feedback property of a closed loop using a tiny one-dimensional world. This is an engineering teaching model, not a biological claim.

# %% [markdown]
# ## Before coding
#
# Start at position 0 with target 2.
#
# After each step, observe the **current** position again before choosing the next action. Predict the trace for four steps.

# %% [markdown]
# ## Implement the function
#
# ### What does this function do?
#
# `closed_loop_trace()` runs a deterministic toy closed loop. On every step, the current position is compared with the target again, then the action moves one unit toward the target or stays still if already there.
#
# ### Inputs
#
# - `initial_position`: environment position before step 0;
# - `target_position`: fixed target used by the toy sensory rule;
# - `steps`: number of feedback/update steps; assume `steps >= 0`.
#
# ### Output
#
# Return one list of positions:
#
# - item 0 is the initial position;
# - each following item is the position **after** one closed-loop step;
# - the list length is therefore `steps + 1`;
# - each step moves by +1, -1, or 0 toward the target.
#
# Do not overshoot the target.

# %%
def closed_loop_trace(
    initial_position: int,
    target_position: int,
    steps: int,
) -> list[int]:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: move one position unit toward the target on every closed-loop step")
    # YOUR CODE ENDS HERE

# %% [markdown]
# ## Check your implementation
#
# The grader checks the core semantics without displaying concrete hidden test vectors in the workbook.

# %%
# Course infrastructure: make the repository root importable from a notebook subdirectory.
from pathlib import Path
import sys

_repo_root = next(
    (
        path
        for path in (Path.cwd(), *Path.cwd().parents)
        if (path / "exercises" / "grader").is_dir()
    ),
    None,
)
if _repo_root is None:
    raise FileNotFoundError(
        "Could not find the FPGA-FlyBrain repository root. Open this exercise from inside the repository; preferably create a personal work copy with scripts/start_exercise.py first."
    )
if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

from exercises.grader.lesson22 import check

check(closed_loop_trace=closed_loop_trace, language="en")

# %% [markdown]
# ## Human Check
#
# Where is the feedback in this function? Why would precomputing a fixed action sequence be conceptually different from re-observing the current position every step?
