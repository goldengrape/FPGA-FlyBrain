# %% [markdown]
# # 第 23 课作业：计算 throughput 与 energy per event
#
# 练习两个 benchmark metric，同时不要把 synthetic number 误写成真实 CPU/GPU/FPGA 性能结论。

# %% [markdown]
# ## 先不用代码
#
# 一次 run 在 0.4 s 内处理 1,200 个 event，平均 power=15 W。
#
# 先手算：
# - events per second；
# - total energy（joule）；
# - joules per event。

# %% [markdown]
# ## 实现函数
#
# ### 这个函数做什么？
#
# `benchmark_metrics()` 把一份文档化 benchmark run 转成 throughput 与 energy per event。
#
# ### 输入
#
# - `events`：完成的 work unit 数；假设 `events > 0`；
# - `seconds`：测得 run duration（秒）；假设 `seconds > 0`；
# - `watts`：同一时间区间的 average measured power；假设 `watts >= 0`。
#
# ### 输出
#
# 返回 `(throughput, energy_per_event)`：
#
# 1. `throughput = events / seconds`，单位 events/s；
# 2. total energy = `watts * seconds` joules；
# 3. `energy_per_event = total_energy / events`，单位 J/event。
#
# 函数只负责计算 metric；它不判断两次 run 是否具有 comparability。

# %%
def benchmark_metrics(
    events: int,
    seconds: float,
    watts: float,
) -> tuple[float, float]:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: return throughput and energy per event")
    # YOUR CODE ENDS HERE

# %% [markdown]
# ## 检查你的实现
#
# grader 会检查核心语义，但不会在作业页展示具体隐藏测试向量。

# %%
# Course infrastructure: make the repository root importable from a notebook subdirectory.
from pathlib import Path
import sys

_repo_root = next(
    (
        path
        for path in (Path.cwd(), *Path.cwd().parents)
        if (path / "exercises" / "grader").is_dir()
    ),
    None,
)
if _repo_root is None:
    raise FileNotFoundError(
        "未找到 FPGA-FlyBrain 仓库根目录。请从仓库内部打开此作业 Notebook；推荐先用 scripts/start_exercise.py 创建个人作业副本。"
    )
if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

from exercises.grader.lesson23 import check

check(benchmark_metrics=benchmark_metrics, language="zh")

# %% [markdown]
# ## Human Check
#
# 两次 run 的 throughput 完全相同。还需要哪些信息，才能讨论某个 CPU/GPU/FPGA implementation 是否更好？
