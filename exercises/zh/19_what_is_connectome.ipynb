# %% [markdown]
# # 第 19 课作业：计算 connectome 的 in-degree 与 out-degree
#
# 练习把 connectome 当成有向图处理，同时不要把 graph structure 与 dynamic neuron state 混在一起。

# %% [markdown]
# ## 先不用代码
#
# 给定 neuron IDs `[10, 20, 30]` 与 edges `[(10, 20), (10, 30)]`，先手算每个 neuron 的 in-degree 与 out-degree。
#
# 记住方向是 source → target。

# %% [markdown]
# ## 实现函数
#
# ### 这个函数做什么？
#
# `degree_summary()` 为图中的每个 neuron ID 统计有向 incoming edge 与 outgoing edge 数量。
#
# ### 输入
#
# - `neuron_ids`：这张图中所有 neuron ID；
# - `edges`：有向 `(source, target)` pair；
# - 假设 `edges` 中每个 source/target 都存在于 `neuron_ids`。
#
# ### 输出
#
# 返回 `(in_degree, out_degree)`：
#
# 1. `in_degree[id]` 是 target 等于这个 neuron 的 edge 数；
# 2. `out_degree[id]` 是 source 等于这个 neuron 的 edge 数。
#
# `neuron_ids` 中每个 neuron 都必须出现在两个 dictionary 中，包括 degree 为 0 的 neuron。
#
# 不要修改输入 list。

# %%
def degree_summary(
    neuron_ids: list[int],
    edges: list[tuple[int, int]],
) -> tuple[dict[int, int], dict[int, int]]:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: count incoming and outgoing directed edges for every neuron")
    # YOUR CODE ENDS HERE

# %% [markdown]
# ## 检查你的实现
#
# grader 会检查核心语义，但不会在作业页展示具体隐藏测试向量。

# %%
# Course infrastructure: make the repository root importable from a notebook subdirectory.
from pathlib import Path
import sys

_repo_root = next(
    path for path in (Path.cwd(), *Path.cwd().parents)
    if (path / "exercises" / "grader").is_dir()
)
if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

from exercises.grader.lesson19 import check

check(degree_summary=degree_summary, language="zh")

# %% [markdown]
# ## Human Check
#
# 为什么把所有 edge 方向反过来不会改变 edge 总数，却会改变图的含义？哪些 degree 会互换？
