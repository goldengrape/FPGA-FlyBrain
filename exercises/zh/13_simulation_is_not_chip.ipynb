# %% [markdown]
# # 第 13 课作业：读懂一个 timing budget
#
# 不需要 FPGA 板，也不需要运行厂商工具。目标是把 timing report 中最基本的三个量算清楚。

# %% [markdown]
# ## 先不用代码
#
# 给定路径延迟 `[2.0, 4.5, 3.2]` ns 和 5.0 ns clock period，先手算：
#
# 1. critical path 是多少？
# 2. slack 是多少？
# 3. slack 恰好为 0 时，按本课规则是 pass 还是 fail？
# 4. 只缩短 clock period，会改变 RTL 的逻辑功能吗？

# %% [markdown]
# ## 实现函数
#
# ### 这个函数做什么？
#
# `timing_summary()` 把一组非空的组合路径延迟压缩成最小 timing summary。
#
# ### 输入
#
# - `path_delays_ns`：候选路径的延迟，单位 ns；
# - `clock_period_ns`：目标 clock period，单位 ns。
#
# ### 输出
#
# 返回三个值，顺序固定为 `(critical_path_ns, slack_ns, meets_timing)`：
#
# 1. `critical_path_ns`：最大路径延迟；
# 2. `slack_ns = clock_period_ns - critical_path_ns`；
# 3. `meets_timing`：布尔值，slack ≥ 0 时为 `True`。

# %%
def timing_summary(
    path_delays_ns: list[float],
    clock_period_ns: float,
) -> tuple[float, float, bool]:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: compute critical path, slack, and timing result")
    # YOUR CODE ENDS HERE

# %% [markdown]
# ## 检查你的实现
#
# grader 会检查核心语义，但不会在作业页显示具体测试向量。

# %%
# Course infrastructure: make the repository root importable from a notebook subdirectory.
from pathlib import Path
import sys

_repo_root = next(
    path for path in (Path.cwd(), *Path.cwd().parents)
    if (path / "exercises" / "grader").is_dir()
)
if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

from exercises.grader.lesson13 import check

check(timing_summary=timing_summary, language="zh")

# %% [markdown]
# ## Human Check
#
# 说明为什么 critical path 取最大值、负 slack 代表什么，以及 timing pass 为什么不能替代 functional simulation。
