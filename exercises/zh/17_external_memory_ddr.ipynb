# %% [markdown]
# # 第 17 课作业：估算 sequential/random access 的 burst 成本
#
# 不模拟真实 DDR controller，只把 address pattern 转成 burst 数和一个最小周期成本。

# %% [markdown]
# ## 先不用代码
#
# 比较：
#
# - `[0,1,2,3,4]`，max burst=4；
# - `[0,10,20,30,40]`，max burst=4。
#
# 若每 burst setup=5 cycles、每 word=1 cycle，分别需要几个 burst、多少总 cycles？

# %% [markdown]
# ## 实现函数
#
# ### 这个函数做什么？
#
# `estimate_burst_cycles()` 按请求顺序扫描 word address，把连续地址尽量合并到同一 burst，每个 burst 最多 `max_burst_words` 个 word。
#
# ### 输入
#
# - `addresses`：按请求顺序排列的 word index；
# - `max_burst_words`：单 burst 最大 word 数；
# - `setup_cycles`：每开一个 burst 的固定成本；
# - `word_cycles`：每传一个 word 的成本。
#
# ### 输出
#
# 返回 `(burst_count, total_cycles)`：
#
# - 空列表返回 `(0, 0)`；
# - 仅当 `current == previous + 1` 且 burst 未满时继续同一 burst；
# - `total_cycles = burst_count * setup_cycles + len(addresses) * word_cycles`。

# %%
def estimate_burst_cycles(
    addresses: list[int],
    max_burst_words: int,
    setup_cycles: int,
    word_cycles: int = 1,
) -> tuple[int, int]:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: group consecutive addresses into bursts and compute cycles")
    # YOUR CODE ENDS HERE

# %% [markdown]
# ## 检查你的实现
#
# grader 会检查核心语义，但不会在作业页显示具体测试向量。

# %%
# Course infrastructure: make the repository root importable from a notebook subdirectory.
from pathlib import Path
import sys

_repo_root = next(
    path for path in (Path.cwd(), *Path.cwd().parents)
    if (path / "exercises" / "grader").is_dir()
)
if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

from exercises.grader.lesson17 import check

check(estimate_burst_cycles=estimate_burst_cycles, language="zh")

# %% [markdown]
# ## Human Check
#
# 说明为什么相同 word 数可能有不同 burst_count；为什么这只是 access-pattern 模型；为什么 integrity test 应先于 bandwidth benchmark。
