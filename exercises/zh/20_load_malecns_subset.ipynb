# %% [markdown]
# # 第 20 课作业：建立带 provenance 的 image manifest
#
# 练习在真实 MaleCNS subset 装载之前建立 image integrity contract。这里的 payload 只是普通 bytes；本作业不声称包含真实 MaleCNS 数据。

# %% [markdown]
# ## 先不用代码
#
# 假设两个文件名字一样、bytes 也一样，但一个来自 source release A，另一个来自 source release B。checksum 能告诉你这两个来源不同吗？
#
# 为了让另一台机器同时验证**精确 payload**和**它的来源/转换规则**，manifest 还需要记录什么？

# %% [markdown]
# ## 实现函数
#
# ### 这个函数做什么？
#
# `image_manifest()` 为一份精确 binary payload 建立包含 integrity 与 provenance 的最小教学 manifest。
#
# ### 输入
#
# - `payload`：精确 image bytes；
# - `schema_version`：说明这些 bytes 应如何解释的 schema version；
# - `source_release`：源数据 release / fixture 标识；
# - `converter_version`：产生这份 image 的 converter version。
#
# ### 输出
#
# 返回一个 dictionary，且**恰好**包含这些 key：
#
# - `"schema_version"`：复制输入 schema version；
# - `"source_release"`：复制输入 source release；
# - `"converter_version"`：复制输入 converter version；
# - `"byte_count"`：`len(payload)`；
# - `"sha256"`：精确 payload bytes 的小写十六进制 SHA-256 digest。
#
# 函数必须 deterministic，并且不能修改 `payload`。

# %%
import hashlib

def image_manifest(
    payload: bytes,
    schema_version: str,
    source_release: str,
    converter_version: str,
) -> dict[str, object]:
    # YOUR CODE STARTS HERE
    raise NotImplementedError(
        "TODO: return schema/provenance fields, byte count, and SHA-256 digest"
    )
    # YOUR CODE ENDS HERE

# %% [markdown]
# ## 检查你的实现
#
# grader 会检查核心语义，但不会在作业页展示具体隐藏测试向量。

# %%
# Course infrastructure: make the repository root importable from a notebook subdirectory.
from pathlib import Path
import sys

_repo_root = next(
    path for path in (Path.cwd(), *Path.cwd().parents)
    if (path / "exercises" / "grader").is_dir()
)
if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

from exercises.grader.lesson20 import check

check(image_manifest=image_manifest, language="zh")

# %% [markdown]
# ## Human Check
#
# 如果两个 consumer 的 SHA-256 相同，但 `source_release` 或 `converter_version` 不同，说明什么？在你的实现中，哪几行负责 integrity，哪几行负责 provenance？
