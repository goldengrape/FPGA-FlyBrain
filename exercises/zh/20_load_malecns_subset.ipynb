# %% [markdown]
# # 第 20 课作业：建立最小 image manifest
#
# 练习 software-vs-FPGA differential test 之前需要的 integrity contract。这里的 payload 只是普通 bytes；本作业不声称包含真实 MaleCNS 数据。

# %% [markdown]
# ## 先不用代码
#
# 假设两个文件名字完全一样，但 bytes 不同。文件名能证明它们是同一 image 吗？
#
# 为了让另一台机器验证精确 payload，你会记录哪些信息？

# %% [markdown]
# ## 实现函数
#
# ### 这个函数做什么？
#
# `image_manifest()` 为一份精确 binary payload 建立最小 integrity 描述。
#
# ### 输入
#
# - `payload`：精确 image bytes；
# - `schema_version`：说明这些 bytes 应如何解释的 version string。
#
# ### 输出
#
# 返回一个 dictionary，且恰好包含这些 key：
#
# - `"schema_version"`：复制输入 version string；
# - `"byte_count"`：`len(payload)`；
# - `"sha256"`：精确 payload bytes 的小写十六进制 SHA-256 digest。
#
# 函数必须 deterministic，并且不能修改 `payload`。

# %%
import hashlib

def image_manifest(
    payload: bytes,
    schema_version: str,
) -> dict[str, object]:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: return schema version, byte count, and SHA-256 digest")
    # YOUR CODE ENDS HERE

# %% [markdown]
# ## 检查你的实现
#
# grader 会检查核心语义，但不会在作业页展示具体隐藏测试向量。

# %%
# Course infrastructure: make the repository root importable from a notebook subdirectory.
from pathlib import Path
import sys

_repo_root = next(
    path for path in (Path.cwd(), *Path.cwd().parents)
    if (path / "exercises" / "grader").is_dir()
)
if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

from exercises.grader.lesson20 import check

check(image_manifest=image_manifest, language="zh")

# %% [markdown]
# ## Human Check
#
# 如果两个 consumer 报告相同 SHA-256 digest，已经证明了什么？关于 neural correctness 又有哪些事情**还没有**被证明？
