# %% [markdown]
# # 第 21 课作业：找出 utilization 最高的 stage
#
# 练习用 demand 相对于 capacity 的比例诊断 bottleneck，而不是只看 raw workload。

# %% [markdown]
# ## 先不用代码
#
# Stage A 的 demand=6、capacity=12；Stage B 的 demand=6、capacity=8。
#
# 两个 stage 的 raw demand 相同。分别算 utilization，再判断哪个 stage 更接近容量上限。

# %% [markdown]
# ## 实现函数
#
# ### 这个函数做什么？
#
# `bottleneck()` 把每个 stage 的 demand/capacity 转成 utilization，并找出当前 utilization 最高的 stage。
#
# ### 输入
#
# - `stage_demand`：stage name → required work rate；
# - `stage_capacity`：相同 stage name → available work rate；
# - 假设两个 dictionary 拥有相同 key；
# - 假设所有 capacity 都大于 0；
# - grader case 中最高 utilization 唯一。
#
# ### 输出
#
# 返回 `(utilization, bottleneck_stage)`：
#
# 1. `utilization[stage] = stage_demand[stage] / stage_capacity[stage]`；
# 2. `bottleneck_stage` 是 utilization 最高的 stage name。
#
# 不要修改输入 dictionary。

# %%
def bottleneck(
    stage_demand: dict[str, float],
    stage_capacity: dict[str, float],
) -> tuple[dict[str, float], str]:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: compute utilization and return the highest-utilization stage")
    # YOUR CODE ENDS HERE

# %% [markdown]
# ## 检查你的实现
#
# grader 会检查核心语义，但不会在作业页展示具体隐藏测试向量。

# %%
# Course infrastructure: make the repository root importable from a notebook subdirectory.
from pathlib import Path
import sys

_repo_root = next(
    (
        path
        for path in (Path.cwd(), *Path.cwd().parents)
        if (path / "exercises" / "grader").is_dir()
    ),
    None,
)
if _repo_root is None:
    raise FileNotFoundError(
        "未找到 FPGA-FlyBrain 仓库根目录。请从仓库内部打开此作业 Notebook；推荐先用 scripts/start_exercise.py 创建个人作业副本。"
    )
if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

from exercises.grader.lesson21 import check

check(bottleneck=bottleneck, language="zh")

# %% [markdown]
# ## Human Check
#
# 为什么 raw demand 较小的 stage 仍可能成为 bottleneck？提出 hardware optimization 前，你还希望看到什么 measurement？
