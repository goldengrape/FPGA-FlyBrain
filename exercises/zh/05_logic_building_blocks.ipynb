# %% [markdown]
# # 第 5 课作业：从真值表到 spike 条件
#
# 这份作业对应 **第 5 课：数字电路有哪些最基本的逻辑积木？**
#
# 本题的重点不是记住 Python 的 and/or/not 写法，而是从 **truth table → Boolean relation → 组合逻辑** 建立映射。

# %% [markdown]
# ## 本题目标
#
# 你会实现 NOT、AND、OR，再把 threshold comparator 的真假结果与 enable 组合成 spike 条件。
#
# threshold_reached 的 specification 已冻结：当 value 达到或超过 threshold 时返回 True。spike_enabled 已经给出，不需要修改。

# %% [markdown]
# ## 先不用代码：把逻辑关系写清楚
#
# 先填下面两张表。
#
# ### A. 两输入逻辑
#
# | a | b | a AND b | a OR b |
# |---|---|---|---|
# | False | False | ? | ? |
# | False | True  | ? | ? |
# | True  | False | ? | ? |
# | True  | True  | ? | ? |
#
# 再写出 NOT False 与 NOT True。
#
# ### B. comparator + enable
#
# 只考虑三种 value 位置：低于 threshold、恰好等于 threshold、高于 threshold。
#
# 先判断 threshold_reached 应该是什么，再思考 enable=False 时最终 spike 为什么始终被挡住。

# %% [markdown]
# ## Part A：实现基本 gates
#
# ### 这些函数做什么？
#
# 这一部分实现三个最基本的 Boolean gate。它们都只处理 `True / False`，不保存状态，也没有时间步。
#
# ### 输入与输出
#
# - `gate_not(a)`
#   输入一个布尔值 `a`；返回 **一个布尔值**，表示 `NOT a`。
#
# - `gate_and(a, b)`
#   输入两个布尔值 `a`、`b`；返回 **一个布尔值**。只有两个输入都为 `True` 时结果才为 `True`。
#
# - `gate_or(a, b)`
#   输入两个布尔值 `a`、`b`；返回 **一个布尔值**。只要至少一个输入为 `True`，结果就是 `True`。
#
# 请根据前面的 truth table 实现逻辑关系，而不是只记 Python 语法。

# %%
def gate_not(a: bool) -> bool:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: NOT")
    # YOUR CODE ENDS HERE


def gate_and(a: bool, b: bool) -> bool:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: AND")
    # YOUR CODE ENDS HERE


def gate_or(a: bool, b: bool) -> bool:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: OR")
    # YOUR CODE ENDS HERE

# %% [markdown]
# ## Part B：实现 threshold comparator
#
# ### 这个函数做什么？
#
# `threshold_reached()` 把一个数值比较变成一个 Boolean 条件。
#
# ### 输入
#
# - `value`：要检查的当前数值；
# - `threshold`：阈值。
#
# ### 输出
#
# 返回 **一个布尔值**：
#
# - `True`：`value` 达到或超过 `threshold`；
# - `False`：`value` 仍低于 `threshold`。
#
# 下面的 `spike_enabled()` 已经替你写好。它返回一个布尔值，表示“enable 已开启 **并且** threshold 已达到”时才允许 spike。你不需要修改它，但应该能读懂 comparator 的 Boolean 输出是怎样送进 AND 的。

# %%
def threshold_reached(value: int, threshold: int) -> bool:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: threshold comparison")
    # YOUR CODE ENDS HERE


def spike_enabled(enable: bool, value: int, threshold: int) -> bool:
    return gate_and(enable, threshold_reached(value, threshold))

# %% [markdown]
# ## 检查你的实现
#
# grader 会检查完整 Boolean 行为、threshold boundary 和 enable 组合，但不会在 Notebook 中显示具体测试向量。

# %%
# Course infrastructure: make the repository root importable from a notebook subdirectory.
from pathlib import Path
import sys

_repo_root = next(
    path for path in (Path.cwd(), *Path.cwd().parents)
    if (path / "exercises" / "grader").is_dir()
)
if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

from exercises.grader.lesson05 import check

check(
    gate_not=gate_not,
    gate_and=gate_and,
    gate_or=gate_or,
    threshold_reached=threshold_reached,
    spike_enabled=spike_enabled,
    language="zh",
)

# %% [markdown]
# ## Human Check
#
# 用“如果写错会怎样”检查自己的实现：
#
# 1. 如果 gate_and() 被误写成 OR，什么类型的输入组合最容易暴露错误？为什么？
# 2. 如果 threshold_reached() 错用了严格大于号，哪一类边界输入会与 specification 分叉？
# 3. 如果 spike_enabled() 把 AND 错换成 OR，会出现哪一种“enable 已关闭却仍然 spike”的错误路径？
# 4. 从你的代码画回硬件关系：comparator 的输出是什么，AND 的两个输入分别来自哪里，最终输出是什么？
