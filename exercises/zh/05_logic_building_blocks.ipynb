# %% [markdown]
# # 第 5 课作业：逻辑门、比较器与 enable
#
# 这份作业对应 **第 5 课：数字电路有哪些最基本的逻辑积木？**
#
# 这一课把 Python 布尔表达式当成数字逻辑的最小模型。你会实现 NOT、AND、OR 和 threshold comparator，再观察 enable 如何组合进 spike 决策。

# %% [markdown]
# ## 任务与约束
#
# 完成 gate_not、gate_and、gate_or 和 threshold_reached。
#
# threshold_reached 的课程语义已经固定：当 value 达到或超过 threshold 时返回 True。
#
# spike_enabled 已经写好。不要改它；它用来展示简单逻辑如何组合成更大的条件。

# %% [markdown]
# ## 编写你的实现
#
# 只修改下面 TODO 区域。函数签名是本课接口的一部分。

# %%
def gate_not(a: bool) -> bool:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: NOT")
    # YOUR CODE ENDS HERE


def gate_and(a: bool, b: bool) -> bool:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: AND")
    # YOUR CODE ENDS HERE


def gate_or(a: bool, b: bool) -> bool:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: OR")
    # YOUR CODE ENDS HERE


def threshold_reached(value: int, threshold: int) -> bool:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: threshold comparison")
    # YOUR CODE ENDS HERE


def spike_enabled(enable: bool, value: int, threshold: int) -> bool:
    return gate_and(enable, threshold_reached(value, threshold))

# %% [markdown]
# ## 检查你的实现
#
# 下面的单元只调用外部 grader。具体测试输入不会显示在作业 Notebook 中。先运行上面的实现单元，再运行这里。

# %%
from exercises.grader.lesson05 import check

check(
    gate_not=gate_not,
    gate_and=gate_and,
    gate_or=gate_or,
    threshold_reached=threshold_reached,
    spike_enabled=spike_enabled,
    language="zh",
)

# %% [markdown]
# ## Human Check
#
# 1. 为什么 threshold 的“等于”情况值得单独思考？
# 2. spike_enabled 可以画成哪些基本逻辑块的组合？
# 3. enable=False 时，即使 comparator 已经为 True，最终输出为什么仍应为 False？
