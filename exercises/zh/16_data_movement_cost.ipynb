# %% [markdown]
# # 第 16 课作业：判断 compute 还是 data movement 更可能限制系统
#
# 使用第 16 课的**分项成本简化模型**。目标是把单位与数量关系算清楚，并比较 compute cost 与 transfer cost；它不是最终系统总运行时间模型。

# %% [markdown]
# ## 先不用代码
#
# 先手算：100 items、8 bytes/item、2 ns compute/item、2 bytes/ns bandwidth、20 ns startup latency。
#
# 分别得到 compute time 与 transfer time，并判断谁更大。

# %% [markdown]
# ## 实现函数
#
# ### 这个函数做什么？
#
# `transfer_profile()` 比较一批 item 的算术时间与数据搬运时间。
#
# ### 输入
#
# - `num_items`：item 数；
# - `bytes_per_item`：每 item 搬运的 bytes；
# - `compute_ns_per_item`：每 item 计算时间；
# - `bandwidth_bytes_per_ns`：有效 bandwidth；
# - `startup_latency_ns`：一次批量传输的固定延迟。
#
# **本题有效输入域：** `num_items >= 0`、`bytes_per_item >= 0`、`compute_ns_per_item >= 0`、`startup_latency_ns >= 0`，且 `bandwidth_bytes_per_ns > 0`。本题不要求处理无效输入。
#
# ### 输出
#
# 返回 `(compute_ns, transfer_ns, bottleneck)`：
#
# - `compute_ns = num_items * compute_ns_per_item`；
# - `transfer_ns = startup_latency_ns + num_items * bytes_per_item / bandwidth_bytes_per_ns`；
# - bottleneck 为 `"compute"`、`"memory"`，两者相等时为 `"balanced"`。

# %%
def transfer_profile(
    num_items: int,
    bytes_per_item: int,
    compute_ns_per_item: float,
    bandwidth_bytes_per_ns: float,
    startup_latency_ns: float = 0.0,
) -> tuple[float, float, str]:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: compute compute time, transfer time, and bottleneck")
    # YOUR CODE ENDS HERE

# %% [markdown]
# ## 检查你的实现
#
# grader 会检查核心语义，但不会在作业页显示具体测试向量。

# %%
# Course infrastructure: make the repository root importable from a notebook subdirectory.
from pathlib import Path
import sys

_repo_root = next(
    path for path in (Path.cwd(), *Path.cwd().parents)
    if (path / "exercises" / "grader").is_dir()
)
if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

from exercises.grader.lesson16 import check

check(transfer_profile=transfer_profile, language="zh")

# %% [markdown]
# ## Human Check
#
# 说明为什么本题只比较 compute cost 与 transfer cost，而不把较大值当成完整 elapsed time；bandwidth 单位为什么必须匹配；bottleneck 改变为什么不等于 neuron semantics 改变。
