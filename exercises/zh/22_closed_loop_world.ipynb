# %% [markdown]
# # 第 22 课作业：生成 deterministic closed-loop position trace
#
# 用一个极小的一维 world 练习 closed loop 的 feedback 特征。这是工程教学模型，不是 biological claim。

# %% [markdown]
# ## 先不用代码
#
# 从 position 0 开始，target=2。
#
# 每一步之后，都要重新观察**当前** position，再决定下一次 action。先预测四步后的 trace。

# %% [markdown]
# ## 实现函数
#
# ### 这个函数做什么？
#
# `closed_loop_trace()` 运行一个 deterministic toy closed loop。每一步都重新比较当前 position 与 target，然后向 target 移动一个单位；如果已经到达 target，就保持不动。
#
# ### 输入
#
# - `initial_position`：step 0 之前的 environment position；
# - `target_position`：toy sensory rule 使用的固定 target；
# - `steps`：feedback/update step 数；假设 `steps >= 0`。
#
# ### 输出
#
# 返回一个 position list：
#
# - item 0 是 initial position；
# - 后续每一项都是完成一个 closed-loop step **之后**的 position；
# - list 长度因此是 `steps + 1`；
# - 每一步只能向 target 移动 +1、-1 或保持 0。
#
# 不能越过 target。

# %%
def closed_loop_trace(
    initial_position: int,
    target_position: int,
    steps: int,
) -> list[int]:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: move one position unit toward the target on every closed-loop step")
    # YOUR CODE ENDS HERE

# %% [markdown]
# ## 检查你的实现
#
# grader 会检查核心语义，但不会在作业页展示具体隐藏测试向量。

# %%
# Course infrastructure: make the repository root importable from a notebook subdirectory.
from pathlib import Path
import sys

_repo_root = next(
    (
        path
        for path in (Path.cwd(), *Path.cwd().parents)
        if (path / "exercises" / "grader").is_dir()
    ),
    None,
)
if _repo_root is None:
    raise FileNotFoundError(
        "未找到 FPGA-FlyBrain 仓库根目录。请从仓库内部打开此作业 Notebook；推荐先用 scripts/start_exercise.py 创建个人作业副本。"
    )
if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

from exercises.grader.lesson22 import check

check(closed_loop_trace=closed_loop_trace, language="zh")

# %% [markdown]
# ## Human Check
#
# 这个函数里的 feedback 在哪里？为什么预先写死一串 action sequence，与每一步重新观察当前 position 在概念上不同？
