# %% [markdown]
# # 第 3 课作业：把“LIF”变成明确的 specification
#
# 这份作业对应 **第 3 课：“都叫 LIF”为什么还不够？**
#
# 这次不只是“实现一个函数”。你还要亲手设计能让错误语义暴露出来的输入。

# %% [markdown]
# ## 本课冻结的 v0 contract
#
# - candidate = alpha * v + current
# - candidate 达到或超过 threshold 时 spike
# - spike 后立即 reset
# - lif_step_v0 返回 (next_v, spike, candidate_v)
#
# 后两个任务不是让你猜老师的测试数据，而是让你自己构造 **distinguishing probe**：一个输入必须能让两种候选规则给出不同结果。

# %% [markdown]
# ## 先不用代码：哪一种输入最有区分力？
#
# 考虑两组规则。
#
# ### A. threshold 比较
#
# - 规则 1：candidate >= threshold
# - 规则 2：candidate > threshold
#
# 什么样的 candidate 最能区分它们？
#
# ### B. update order
#
# - 规则 1：alpha * v + current
# - 规则 2：alpha * (v + current)
#
# 请自己选一组 0 < alpha < 1、current != 0 的数，先手算两式，确认结果真的不同。
#
# 如果两种规则在你选的输入上结果相同，这个输入就不是好的 distinguishing probe。

# %% [markdown]
# ## Part A：实现 frozen v0 semantics

# %%
def lif_step_v0(
    v: float,
    current: float,
    alpha: float = 0.9,
    threshold: float = 1.0,
    reset: float = 0.0,
) -> tuple[float, bool, float]:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: implement the frozen v0 semantics")
    # YOUR CODE ENDS HERE

    return next_v, spike, candidate_v

# %% [markdown]
# ## Part B：构造 threshold boundary probe
#
# 返回一组 (v, current, alpha, threshold)，使 v0 candidate 恰好落在 threshold 上。不要修改函数签名。
#
# 为了让这一步真正成为“自己设计 probe”，请不要直接复用教材里的 v=0.75、current=0.25 那组数字；自己选一组满足边界条件的值。

# %%
def threshold_boundary_case() -> tuple[float, float, float, float]:
    # Return (v, current, alpha, threshold)
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: construct a threshold boundary case")
    # YOUR CODE ENDS HERE

# %% [markdown]
# ## Part C：构造 update-order counterexample
#
# 返回一组 (v, current, alpha)，让两种 update order 产生不同结果。
#
# 同样请不要直接复用教材里的 v=0.8、current=0.4、alpha=0.9；自己找一组 0 < alpha < 1 且 current != 0 的数。

# %%
def update_order_counterexample() -> tuple[float, float, float]:
    # Return (v, current, alpha)
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: construct an update-order counterexample")
    # YOUR CODE ENDS HERE

# %% [markdown]
# ## 检查你的实现
#
# grader 不要求你使用某一组固定 probe；它检查的是你构造的例子是否真的具有区分能力。

# %%
# Course infrastructure: make the repository root importable from a notebook subdirectory.
from pathlib import Path
import sys

_repo_root = next(
    path for path in (Path.cwd(), *Path.cwd().parents)
    if (path / "exercises" / "grader").is_dir()
)
if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

from exercises.grader.lesson03 import check

check(
    lif_step_v0=lif_step_v0,
    threshold_boundary_case=threshold_boundary_case,
    update_order_counterexample=update_order_counterexample,
    language="zh",
)

# %% [markdown]
# ## Human Check
#
# 1. 指着你自己的 threshold probe，解释为什么它能区分 >= 与 >。
# 2. 指着你自己的 update-order counterexample，解释差异来自哪里。
# 3. 两个人给出完全不同的数字，是否都可能构造出有效的 distinguishing probe？真正必须满足的性质是什么？
# 4. 举一个“看起来像测试、但其实不能区分两种规则”的坏 probe，并说明它为什么没有信息量。
# 5. 如果以后 RTL 与 Python 不一致，你会按什么顺序比较 input、candidate、spike、stored state 来定位第一处分叉？
