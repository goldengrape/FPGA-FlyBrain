# %% [markdown]
# # 第 18 课作业：找出 VALID/READY 真正接受的 data beat
#
# 只训练高级可扩展接口（Advanced eXtensible Interface, AXI）风格 handshake 的最小规则，不要求实现完整 AXI channel。

# %% [markdown]
# ## 先不用代码
#
# 手工看：
#
# - VALID = `[1,1,1,0]`
# - READY = `[1,0,1,1]`
# - DATA = `[5,6,6,9]`
#
# 哪些 cycle 真正发生 transfer？为什么 cycle 1 的 DATA=6 不能算已接受？

# %% [markdown]
# ## 实现函数
#
# ### 这个函数做什么？
#
# `accepted_beats()` 从逐 cycle 的 VALID/READY/data trace 中抽取真正完成传输的 beat。假设三个列表长度相同。
#
# 这份 trace **假设发送方已经遵守协议稳定性规则**：如果 VALID=1 但 READY=0，那么在真正接受前 VALID 与对应 payload 保持稳定。本函数只抽取已接受 beat，不负责验证 trace 是否违反协议。
#
# ### 输入
#
# - `valid[cycle]`：sender 是否声明 payload 有效；
# - `ready[cycle]`：receiver 是否能接收；
# - `data[cycle]`：当前 payload。
#
# ### 输出
#
# 返回 `(accepted_data, accepted_cycles)`：
#
# - 只有 `valid[cycle] and ready[cycle]` 同时为真时才接受；
# - `accepted_data` 按时间顺序保存 data；
# - `accepted_cycles` 保存发生 transfer 的 cycle index。

# %%
def accepted_beats(
    valid: list[bool],
    ready: list[bool],
    data: list[int],
) -> tuple[list[int], list[int]]:
    accepted_data: list[int] = []
    accepted_cycles: list[int] = []

    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: accept beats only where VALID and READY are both true")
    # YOUR CODE ENDS HERE

    return accepted_data, accepted_cycles

# %% [markdown]
# ## 检查你的实现
#
# grader 会检查核心语义，但不会在作业页显示具体测试向量。

# %%
# Course infrastructure: make the repository root importable from a notebook subdirectory.
from pathlib import Path
import sys

_repo_root = next(
    path for path in (Path.cwd(), *Path.cwd().parents)
    if (path / "exercises" / "grader").is_dir()
)
if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

from exercises.grader.lesson18 import check

check(accepted_beats=accepted_beats, language="zh")

# %% [markdown]
# ## Human Check
#
# 说明 VALID=1/READY=0 为什么是 stall 而不是 transfer，READY=1/VALID=0 为什么也没有 payload，以及它与第 10 课 backpressure 的关系。
