# %% [markdown]
# # 第 15 课作业：模拟 host ↔ programmable logic 往返
#
# 用一个很小的命令序列模拟 host 与 PL 的控制语义。它不是 AXI 实现，重点是 state persistence 与顺序。

# %% [markdown]
# ## 先不用代码
#
# 从 `initial_register=3` 开始手工追踪：
#
# `[("read", None), ("add", 4), ("read", None), ("write", 1), ("read", None)]`
#
# 写出每次 read 的结果和最终 register。

# %% [markdown]
# ## 实现函数
#
# ### 这个函数做什么？
#
# `run_host_pl_commands()` 按顺序执行 host 命令，并把 `register` 当作 PL 中持续存在的 state。
#
# ### 输入
#
# - `commands`：每项是 `(op, value)`；
# - `"write"`：`register = value`；
# - `"add"`：`register += value`；
# - `"read"`：把当前 register 追加到 readbacks，忽略 value；
# - `initial_register`：第一条命令前的 PL register。
#
# ### 输出
#
# 返回 `(readbacks, final_register)`。readbacks 必须保持 read 命令发生的时间顺序。

# %%
def run_host_pl_commands(
    commands: list[tuple[str, int | None]],
    initial_register: int = 0,
) -> tuple[list[int], int]:
    register = initial_register
    readbacks: list[int] = []

    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: execute write/add/read commands in order")
    # YOUR CODE ENDS HERE

    return readbacks, register

# %% [markdown]
# ## 检查你的实现
#
# grader 会检查核心语义，但不会在作业页显示具体测试向量。

# %%
# Course infrastructure: make the repository root importable from a notebook subdirectory.
from pathlib import Path
import sys

_repo_root = next(
    path for path in (Path.cwd(), *Path.cwd().parents)
    if (path / "exercises" / "grader").is_dir()
)
if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

from exercises.grader.lesson15 import check

check(run_host_pl_commands=run_host_pl_commands, language="zh")

# %% [markdown]
# ## Human Check
#
# 说明为什么 register 必须跨命令保留，为什么 read 只观察、不修改，以及这个 Python 模型与真实 host↔FPGA transaction 的边界。
