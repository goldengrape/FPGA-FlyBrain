# %% [markdown]
# # 第 14 课作业：把板上时钟变成可观察 tick
#
# 把高速 board clock 翻译成一个慢得多的可观察 tick。假设输入频率能被目标 tick 频率整除。

# %% [markdown]
# ## 先不用代码
#
# 先算：
#
# - 12 Hz 输入、3 Hz target tick：每个 tick 需要几个 cycle？
# - counter 表示 `0..cycles_per_tick-1` 时，至少要多少 bit？
# - 若每个 cycle 就产生一次 tick，本作业规定 counter width 最少返回 1 bit。

# %% [markdown]
# ## 实现函数
#
# ### 这个函数做什么？
#
# `clock_divider_plan()` 为第一个 board counter 实验计算最小参数。
#
# ### 输入
#
# - `input_clock_hz`：输入 clock 每秒 cycle 数；
# - `target_tick_hz`：希望每秒产生多少个慢速 tick。
#
# 两个值都是正整数，且这里假设可以整除。本题不要求处理 0、负数或不能整除的输入。
#
# ### 输出
#
# 返回 `(cycles_per_tick, counter_bits)`：
#
# 1. `cycles_per_tick = input_clock_hz // target_tick_hz`；
# 2. `counter_bits` 是表示 `0..cycles_per_tick-1` 所需的最少 bit 数，最小返回 1。

# %%
def clock_divider_plan(
    input_clock_hz: int,
    target_tick_hz: int,
) -> tuple[int, int]:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: compute cycles per tick and counter width")
    # YOUR CODE ENDS HERE

# %% [markdown]
# ## 检查你的实现
#
# grader 会检查核心语义，但不会在作业页显示具体测试向量。

# %%
# Course infrastructure: make the repository root importable from a notebook subdirectory.
from pathlib import Path
import sys

_repo_root = next(
    path for path in (Path.cwd(), *Path.cwd().parents)
    if (path / "exercises" / "grader").is_dir()
)
if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

from exercises.grader.lesson14 import check

check(clock_divider_plan=clock_divider_plan, language="zh")

# %% [markdown]
# ## Human Check
#
# 说明 clock source、counter state、observable I/O 分别做什么，以及为什么 100 MHz 可以驱动几 Hz 的可见变化。
