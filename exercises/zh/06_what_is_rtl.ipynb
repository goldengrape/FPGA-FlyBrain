# %% [markdown]
# # 第 6 课作业：把一个 RTL 时钟沿翻译成 Python 语义
#
# 这份作业对应 **第 6 课：什么是 RTL？**
#
# 你不需要在这里写 SystemVerilog。任务是把课程里的 `clocked_accumulator` 当成一个已经存在的 RTL module，准确说出一个上升沿之后 register 里应该保存什么。

# %% [markdown]
# ## 先不用代码
#
# 先手算两个上升沿：
#
# 1. edge 前 `state=7`、`input_value=-2`、`rst_n=True`，edge 后 state 是多少？
# 2. edge 前 `state=99`、`input_value=3`、`rst_n=False`，edge 后 state 是多少？
#
# 本题只使用不会发生 8-bit overflow 的数值。第 6 课教学 RTL 当前会按有限位宽回绕，但 overflow policy 不是这道作业要冻结的正式神经元语义。

# %% [markdown]
# ## 实现函数
#
# ### 这个函数做什么？
#
# `clocked_accumulator_edge()` 表示 **一个时钟上升沿** 对 `clocked_accumulator` 的状态更新。
#
# ### 输入
#
# - `state`：上升沿到来前 register 保存的旧值；
# - `input_value`：这个上升沿要累加的输入；
# - `rst_n`：同步、低有效 reset；`False` 表示这个上升沿执行 reset。
#
# ### 输出
#
# 返回 **一个整数**，表示这个上升沿结束后 register 中保存的新 `state`：
#
# - 当 `rst_n=False` 时，返回 `0`，reset 优先于累加；
# - 当 `rst_n=True` 时，返回 `state + input_value`。
#
# 函数只描述一个 edge，不在内部保存跨调用的隐藏状态。

# %%
def clocked_accumulator_edge(
    state: int,
    input_value: int,
    rst_n: bool,
) -> int:
    # YOUR CODE STARTS HERE
    raise NotImplementedError("TODO: translate one rising-edge RTL update")
    # YOUR CODE ENDS HERE

# %% [markdown]
# ## 检查你的实现
#
# grader 会分别检查正常累加、reset 优先级，以及把多个 edge 串起来时旧 state 是否真的参与下一次更新。它不会在 Notebook 中显示具体隐藏向量。

# %%
# Course infrastructure: make the repository root importable from a notebook subdirectory.
from pathlib import Path
import sys

_repo_root = next(
    (
        path
        for path in (Path.cwd(), *Path.cwd().parents)
        if (path / "exercises" / "grader").is_dir()
    ),
    None,
)
if _repo_root is None:
    raise FileNotFoundError(
        "Could not find the FPGA-FlyBrain repository root. Open this exercise from inside the repository; preferably create a personal work copy with scripts/start_exercise.py first. / 未找到 FPGA-FlyBrain 仓库根目录。请从仓库内部打开此作业 Notebook；推荐先用 scripts/start_exercise.py 创建个人作业副本。"
    )
if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

from exercises.grader.lesson06 import check

check(
    clocked_accumulator_edge=clocked_accumulator_edge,
    language="zh",
)

# %% [markdown]
# ## Human Check
#
# 1. 为什么 `rst_n=False` 时不能先做 `state + input_value` 再 reset？
# 2. 这个 Python 函数对应 RTL 中哪一类行为：combinational relation 还是 clocked register update？
# 3. 为什么“函数运行正确”仍不等于真实 RTL 已经通过仿真？
# 4. 如果要观察真实 8-bit overflow，应该回到哪个教学 artifact / 工具链，而不是偷偷把 overflow policy 写进这道作业？
